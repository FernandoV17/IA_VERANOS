# %% [markdown]
# <a href="https://colab.research.google.com/github/FernandoV17/IA_VERANOS/blob/main/desicion_tree.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !wget https://raw.githubusercontent.com/FernandoV17/IA_VERANOS/refs/heads/main/decision-tree/data/train.csv
# Out:
# --2025-07-04 04:01:55--  https://raw.githubusercontent.com/FernandoV17/IA_VERANOS/refs/heads/decision-tree/decision-tree/data/train.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 60302 (59K) [text/plain]
# Saving to: ‘train.csv’
#
# train.csv           100%[===================>]  58.89K  --.-KB/s    in 0.01s
#
# 2025-07-04 04:01:55 (4.19 MB/s) - ‘train.csv’ saved [60302/60302]

# %%
#Si Clonaste el Respositorio
data_path = '/content/IA_VERANOS/decision-tree/data/train.csv'

# %%
#Si nada mas usas google collab
data_path = '/content/train.csv'

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import seaborn as sns
import joblib
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, classification_report
from sklearn import tree
from sklearn.preprocessing import MinMaxScaler

# %%
df = pd.read_csv(data_path)

# %%
display(
    df.head().style
    .set_properties(**{'text-align': 'center'})
    .format("{:.2f}", subset=df.select_dtypes(include=['float']).columns)
)
# Out:
# <style type="text/css">
# #T_cbb6b_row0_col0, #T_cbb6b_row0_col1, #T_cbb6b_row0_col2, #T_cbb6b_row0_col3, #T_cbb6b_row0_col4, #T_cbb6b_row0_col5, #T_cbb6b_row0_col6, #T_cbb6b_row0_col7, #T_cbb6b_row0_col8, #T_cbb6b_row0_col9, #T_cbb6b_row0_col10, #T_cbb6b_row0_col11, #T_cbb6b_row1_col0, #T_cbb6b_row1_col1, #T_cbb6b_row1_col2, #T_cbb6b_row1_col3, #T_cbb6b_row1_col4, #T_cbb6b_row1_col5, #T_cbb6b_row1_col6, #T_cbb6b_row1_col7, #T_cbb6b_row1_col8, #T_cbb6b_row1_col9, #T_cbb6b_row1_col10, #T_cbb6b_row1_col11, #T_cbb6b_row2_col0, #T_cbb6b_row2_col1, #T_cbb6b_row2_col2, #T_cbb6b_row2_col3, #T_cbb6b_row2_col4, #T_cbb6b_row2_col5, #T_cbb6b_row2_col6, #T_cbb6b_row2_col7, #T_cbb6b_row2_col8, #T_cbb6b_row2_col9, #T_cbb6b_row2_col10, #T_cbb6b_row2_col11, #T_cbb6b_row3_col0, #T_cbb6b_row3_col1, #T_cbb6b_row3_col2, #T_cbb6b_row3_col3, #T_cbb6b_row3_col4, #T_cbb6b_row3_col5, #T_cbb6b_row3_col6, #T_cbb6b_row3_col7, #T_cbb6b_row3_col8, #T_cbb6b_row3_col9, #T_cbb6b_row3_col10, #T_cbb6b_row3_col11, #T_cbb6b_row4_col0, #T_cbb6b_row4_col1, #T_cbb6b_row4_col2, #T_cbb6b_row4_col3, #T_cbb6b_row4_col4, #T_cbb6b_row4_col5, #T_cbb6b_row4_col6, #T_cbb6b_row4_col7, #T_cbb6b_row4_col8, #T_cbb6b_row4_col9, #T_cbb6b_row4_col10, #T_cbb6b_row4_col11 {
#   text-align: center;
# }
# </style>
# <table id="T_cbb6b" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_cbb6b_level0_col0" class="col_heading level0 col0" >PassengerId</th>
#       <th id="T_cbb6b_level0_col1" class="col_heading level0 col1" >Survived</th>
#       <th id="T_cbb6b_level0_col2" class="col_heading level0 col2" >Pclass</th>
#       <th id="T_cbb6b_level0_col3" class="col_heading level0 col3" >Name</th>
#       <th id="T_cbb6b_level0_col4" class="col_heading level0 col4" >Sex</th>
#       <th id="T_cbb6b_level0_col5" class="col_heading level0 col5" >Age</th>
#       <th id="T_cbb6b_level0_col6" class="col_heading level0 col6" >SibSp</th>
#       <th id="T_cbb6b_level0_col7" class="col_heading level0 col7" >Parch</th>
#       <th id="T_cbb6b_level0_col8" class="col_heading level0 col8" >Ticket</th>
#       <th id="T_cbb6b_level0_col9" class="col_heading level0 col9" >Fare</th>
#       <th id="T_cbb6b_level0_col10" class="col_heading level0 col10" >Cabin</th>
#       <th id="T_cbb6b_level0_col11" class="col_heading level0 col11" >Embarked</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_cbb6b_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_cbb6b_row0_col0" class="data row0 col0" >1</td>
#       <td id="T_cbb6b_row0_col1" class="data row0 col1" >0</td>
#       <td id="T_cbb6b_row0_col2" class="data row0 col2" >3</td>
#       <td id="T_cbb6b_row0_col3" class="data row0 col3" >Braund, Mr. Owen Harris</td>
#       <td id="T_cbb6b_row0_col4" class="data row0 col4" >male</td>
#       <td id="T_cbb6b_row0_col5" class="data row0 col5" >22.00</td>
#       <td id="T_cbb6b_row0_col6" class="data row0 col6" >1</td>
#       <td id="T_cbb6b_row0_col7" class="data row0 col7" >0</td>
#       <td id="T_cbb6b_row0_col8" class="data row0 col8" >A/5 21171</td>
#       <td id="T_cbb6b_row0_col9" class="data row0 col9" >7.25</td>
#       <td id="T_cbb6b_row0_col10" class="data row0 col10" >nan</td>
#       <td id="T_cbb6b_row0_col11" class="data row0 col11" >S</td>
#     </tr>
#     <tr>
#       <th id="T_cbb6b_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_cbb6b_row1_col0" class="data row1 col0" >2</td>
#       <td id="T_cbb6b_row1_col1" class="data row1 col1" >1</td>
#       <td id="T_cbb6b_row1_col2" class="data row1 col2" >1</td>
#       <td id="T_cbb6b_row1_col3" class="data row1 col3" >Cumings, Mrs. John Bradley (Florence Briggs Thayer)</td>
#       <td id="T_cbb6b_row1_col4" class="data row1 col4" >female</td>
#       <td id="T_cbb6b_row1_col5" class="data row1 col5" >38.00</td>
#       <td id="T_cbb6b_row1_col6" class="data row1 col6" >1</td>
#       <td id="T_cbb6b_row1_col7" class="data row1 col7" >0</td>
#       <td id="T_cbb6b_row1_col8" class="data row1 col8" >PC 17599</td>
#       <td id="T_cbb6b_row1_col9" class="data row1 col9" >71.28</td>
#       <td id="T_cbb6b_row1_col10" class="data row1 col10" >C85</td>
#       <td id="T_cbb6b_row1_col11" class="data row1 col11" >C</td>
#     </tr>
#     <tr>
#       <th id="T_cbb6b_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_cbb6b_row2_col0" class="data row2 col0" >3</td>
#       <td id="T_cbb6b_row2_col1" class="data row2 col1" >1</td>
#       <td id="T_cbb6b_row2_col2" class="data row2 col2" >3</td>
#       <td id="T_cbb6b_row2_col3" class="data row2 col3" >Heikkinen, Miss. Laina</td>
#       <td id="T_cbb6b_row2_col4" class="data row2 col4" >female</td>
#       <td id="T_cbb6b_row2_col5" class="data row2 col5" >26.00</td>
#       <td id="T_cbb6b_row2_col6" class="data row2 col6" >0</td>
#       <td id="T_cbb6b_row2_col7" class="data row2 col7" >0</td>
#       <td id="T_cbb6b_row2_col8" class="data row2 col8" >STON/O2. 3101282</td>
#       <td id="T_cbb6b_row2_col9" class="data row2 col9" >7.92</td>
#       <td id="T_cbb6b_row2_col10" class="data row2 col10" >nan</td>
#       <td id="T_cbb6b_row2_col11" class="data row2 col11" >S</td>
#     </tr>
#     <tr>
#       <th id="T_cbb6b_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_cbb6b_row3_col0" class="data row3 col0" >4</td>
#       <td id="T_cbb6b_row3_col1" class="data row3 col1" >1</td>
#       <td id="T_cbb6b_row3_col2" class="data row3 col2" >1</td>
#       <td id="T_cbb6b_row3_col3" class="data row3 col3" >Futrelle, Mrs. Jacques Heath (Lily May Peel)</td>
#       <td id="T_cbb6b_row3_col4" class="data row3 col4" >female</td>
#       <td id="T_cbb6b_row3_col5" class="data row3 col5" >35.00</td>
#       <td id="T_cbb6b_row3_col6" class="data row3 col6" >1</td>
#       <td id="T_cbb6b_row3_col7" class="data row3 col7" >0</td>
#       <td id="T_cbb6b_row3_col8" class="data row3 col8" >113803</td>
#       <td id="T_cbb6b_row3_col9" class="data row3 col9" >53.10</td>
#       <td id="T_cbb6b_row3_col10" class="data row3 col10" >C123</td>
#       <td id="T_cbb6b_row3_col11" class="data row3 col11" >S</td>
#     </tr>
#     <tr>
#       <th id="T_cbb6b_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_cbb6b_row4_col0" class="data row4 col0" >5</td>
#       <td id="T_cbb6b_row4_col1" class="data row4 col1" >0</td>
#       <td id="T_cbb6b_row4_col2" class="data row4 col2" >3</td>
#       <td id="T_cbb6b_row4_col3" class="data row4 col3" >Allen, Mr. William Henry</td>
#       <td id="T_cbb6b_row4_col4" class="data row4 col4" >male</td>
#       <td id="T_cbb6b_row4_col5" class="data row4 col5" >35.00</td>
#       <td id="T_cbb6b_row4_col6" class="data row4 col6" >0</td>
#       <td id="T_cbb6b_row4_col7" class="data row4 col7" >0</td>
#       <td id="T_cbb6b_row4_col8" class="data row4 col8" >373450</td>
#       <td id="T_cbb6b_row4_col9" class="data row4 col9" >8.05</td>
#       <td id="T_cbb6b_row4_col10" class="data row4 col10" >nan</td>
#       <td id="T_cbb6b_row4_col11" class="data row4 col11" >S</td>
#     </tr>
#   </tbody>
# </table>

# %%
columnas_a_excluir = ["PassengerId", "Name", "Sibs", "Parch", "Ticket", "Cabin", "Embarked", "SibSp", "Survived"]
df['Sex'] = df['Sex'].astype(str).str.strip().str.lower()
df['Sex'] = df['Sex'].map({'male': 0, 'female': 1})

print("\nAnálisis de valores nulos en el dataset:")
null_analysis = df.isnull().sum().to_frame('Conteo Nulos')
display(null_analysis.style.set_caption("Conteo de valores nulos por columna"))

key_columns = df.select_dtypes(include=['int', 'float']).columns.tolist()
print("\nValores cero en columnas clave:")
zero_analysis = df.select_dtypes(include=['int', 'float']).isin([0]).sum().to_frame('Conteo Ceros')
display(zero_analysis.style.set_caption("Conteo de valores cero en columnas numéricas"))

# Visualización
plt.figure(figsize=(10, 6))
sns.heatmap(df[key_columns].isin([0, np.nan]), cmap='viridis', cbar=False)
plt.title("Mapa de calor de valores cero/nulos en columnas")
plt.show()

print("\nFilas con valores nulos o ceros problemáticos:")
for col in key_columns:
    zero_or_null = df[df[col].isin([0, np.nan])]
    if not zero_or_null.empty:
        print(f"\n--- {col} ---")
        display(zero_or_null.head())
# Out:
# Análisis de valores nulos en el dataset:
# <style type="text/css">
# </style>
# <table id="T_f4f40" class="dataframe">
#   <caption>Conteo de valores nulos por columna</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_f4f40_level0_col0" class="col_heading level0 col0" >Conteo Nulos</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f4f40_level0_row0" class="row_heading level0 row0" >PassengerId</th>
#       <td id="T_f4f40_row0_col0" class="data row0 col0" >0</td>
#     </tr>
#     <tr>
#       <th id="T_f4f40_level0_row1" class="row_heading level0 row1" >Survived</th>
#       <td id="T_f4f40_row1_col0" class="data row1 col0" >0</td>
#     </tr>
#     <tr>
#       <th id="T_f4f40_level0_row2" class="row_heading level0 row2" >Pclass</th>
#       <td id="T_f4f40_row2_col0" class="data row2 col0" >0</td>
#     </tr>
#     <tr>
#       <th id="T_f4f40_level0_row3" class="row_heading level0 row3" >Name</th>
#       <td id="T_f4f40_row3_col0" class="data row3 col0" >0</td>
#     </tr>
#     <tr>
#       <th id="T_f4f40_level0_row4" class="row_heading level0 row4" >Sex</th>
#       <td id="T_f4f40_row4_col0" class="data row4 col0" >0</td>
#     </tr>
#     <tr>
#       <th id="T_f4f40_level0_row5" class="row_heading level0 row5" >Age</th>
#       <td id="T_f4f40_row5_col0" class="data row5 col0" >177</td>
#     </tr>
#     <tr>
#       <th id="T_f4f40_level0_row6" class="row_heading level0 row6" >SibSp</th>
#       <td id="T_f4f40_row6_col0" class="data row6 col0" >0</td>
#     </tr>
#     <tr>
#       <th id="T_f4f40_level0_row7" class="row_heading level0 row7" >Parch</th>
#       <td id="T_f4f40_row7_col0" class="data row7 col0" >0</td>
#     </tr>
#     <tr>
#       <th id="T_f4f40_level0_row8" class="row_heading level0 row8" >Ticket</th>
#       <td id="T_f4f40_row8_col0" class="data row8 col0" >0</td>
#     </tr>
#     <tr>
#       <th id="T_f4f40_level0_row9" class="row_heading level0 row9" >Fare</th>
#       <td id="T_f4f40_row9_col0" class="data row9 col0" >0</td>
#     </tr>
#     <tr>
#       <th id="T_f4f40_level0_row10" class="row_heading level0 row10" >Cabin</th>
#       <td id="T_f4f40_row10_col0" class="data row10 col0" >687</td>
#     </tr>
#     <tr>
#       <th id="T_f4f40_level0_row11" class="row_heading level0 row11" >Embarked</th>
#       <td id="T_f4f40_row11_col0" class="data row11 col0" >2</td>
#     </tr>
#   </tbody>
# </table>
# Valores cero en columnas clave:
# <style type="text/css">
# </style>
# <table id="T_1afbd" class="dataframe">
#   <caption>Conteo de valores cero en columnas numéricas</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_1afbd_level0_col0" class="col_heading level0 col0" >Conteo Ceros</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_1afbd_level0_row0" class="row_heading level0 row0" >PassengerId</th>
#       <td id="T_1afbd_row0_col0" class="data row0 col0" >0</td>
#     </tr>
#     <tr>
#       <th id="T_1afbd_level0_row1" class="row_heading level0 row1" >Survived</th>
#       <td id="T_1afbd_row1_col0" class="data row1 col0" >549</td>
#     </tr>
#     <tr>
#       <th id="T_1afbd_level0_row2" class="row_heading level0 row2" >Pclass</th>
#       <td id="T_1afbd_row2_col0" class="data row2 col0" >0</td>
#     </tr>
#     <tr>
#       <th id="T_1afbd_level0_row3" class="row_heading level0 row3" >Sex</th>
#       <td id="T_1afbd_row3_col0" class="data row3 col0" >577</td>
#     </tr>
#     <tr>
#       <th id="T_1afbd_level0_row4" class="row_heading level0 row4" >Age</th>
#       <td id="T_1afbd_row4_col0" class="data row4 col0" >0</td>
#     </tr>
#     <tr>
#       <th id="T_1afbd_level0_row5" class="row_heading level0 row5" >SibSp</th>
#       <td id="T_1afbd_row5_col0" class="data row5 col0" >608</td>
#     </tr>
#     <tr>
#       <th id="T_1afbd_level0_row6" class="row_heading level0 row6" >Parch</th>
#       <td id="T_1afbd_row6_col0" class="data row6 col0" >678</td>
#     </tr>
#     <tr>
#       <th id="T_1afbd_level0_row7" class="row_heading level0 row7" >Fare</th>
#       <td id="T_1afbd_row7_col0" class="data row7 col0" >15</td>
#     </tr>
#   </tbody>
# </table>
# Filas con valores nulos o ceros problemáticos:
#
# --- Survived ---
#    PassengerId  Survived  Pclass                            Name  Sex   Age  \
# 0            1         0       3         Braund, Mr. Owen Harris    0  22.0
# 4            5         0       3        Allen, Mr. William Henry    0  35.0
# 5            6         0       3                Moran, Mr. James    0   NaN
# 6            7         0       1         McCarthy, Mr. Timothy J    0  54.0
# 7            8         0       3  Palsson, Master. Gosta Leonard    0   2.0
#
#    SibSp  Parch     Ticket     Fare Cabin Embarked
# 0      1      0  A/5 21171   7.2500   NaN        S
# 4      0      0     373450   8.0500   NaN        S
# 5      0      0     330877   8.4583   NaN        Q
# 6      0      0      17463  51.8625   E46        S
# 7      3      1     349909  21.0750   NaN        S
# --- Sex ---
#    PassengerId  Survived  Pclass                            Name  Sex   Age  \
# 0            1         0       3         Braund, Mr. Owen Harris    0  22.0
# 4            5         0       3        Allen, Mr. William Henry    0  35.0
# 5            6         0       3                Moran, Mr. James    0   NaN
# 6            7         0       1         McCarthy, Mr. Timothy J    0  54.0
# 7            8         0       3  Palsson, Master. Gosta Leonard    0   2.0
#
#    SibSp  Parch     Ticket     Fare Cabin Embarked
# 0      1      0  A/5 21171   7.2500   NaN        S
# 4      0      0     373450   8.0500   NaN        S
# 5      0      0     330877   8.4583   NaN        Q
# 6      0      0      17463  51.8625   E46        S
# 7      3      1     349909  21.0750   NaN        S
# --- Age ---
#     PassengerId  Survived  Pclass                           Name  Sex  Age  \
# 5             6         0       3               Moran, Mr. James    0  NaN
# 17           18         1       2   Williams, Mr. Charles Eugene    0  NaN
# 19           20         1       3        Masselmani, Mrs. Fatima    1  NaN
# 26           27         0       3        Emir, Mr. Farred Chehab    0  NaN
# 28           29         1       3  O'Dwyer, Miss. Ellen "Nellie"    1  NaN
#
#     SibSp  Parch  Ticket     Fare Cabin Embarked
# 5       0      0  330877   8.4583   NaN        Q
# 17      0      0  244373  13.0000   NaN        S
# 19      0      0    2649   7.2250   NaN        C
# 26      0      0    2631   7.2250   NaN        C
# 28      0      0  330959   7.8792   NaN        Q
# --- SibSp ---
#    PassengerId  Survived  Pclass  \
# 2            3         1       3
# 4            5         0       3
# 5            6         0       3
# 6            7         0       1
# 8            9         1       3
#
#                                                 Name  Sex   Age  SibSp  Parch  \
# 2                             Heikkinen, Miss. Laina    1  26.0      0      0
# 4                           Allen, Mr. William Henry    0  35.0      0      0
# 5                                   Moran, Mr. James    0   NaN      0      0
# 6                            McCarthy, Mr. Timothy J    0  54.0      0      0
# 8  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)    1  27.0      0      2
#
#              Ticket     Fare Cabin Embarked
# 2  STON/O2. 3101282   7.9250   NaN        S
# 4            373450   8.0500   NaN        S
# 5            330877   8.4583   NaN        Q
# 6             17463  51.8625   E46        S
# 8            347742  11.1333   NaN        S
# --- Parch ---
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name  Sex   Age  SibSp  Parch  \
# 0                            Braund, Mr. Owen Harris    0  22.0      1      0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...    1  38.0      1      0
# 2                             Heikkinen, Miss. Laina    1  26.0      0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)    1  35.0      1      0
# 4                           Allen, Mr. William Henry    0  35.0      0      0
#
#              Ticket     Fare Cabin Embarked
# 0         A/5 21171   7.2500   NaN        S
# 1          PC 17599  71.2833   C85        C
# 2  STON/O2. 3101282   7.9250   NaN        S
# 3            113803  53.1000  C123        S
# 4            373450   8.0500   NaN        S
# --- Fare ---
#      PassengerId  Survived  Pclass                             Name  Sex  \
# 179          180         0       3              Leonard, Mr. Lionel    0
# 263          264         0       1            Harrison, Mr. William    0
# 271          272         1       3     Tornquist, Mr. William Henry    0
# 277          278         0       2      Parkes, Mr. Francis "Frank"    0
# 302          303         0       3  Johnson, Mr. William Cahoone Jr    0
#
#       Age  SibSp  Parch  Ticket  Fare Cabin Embarked
# 179  36.0      0      0    LINE   0.0   NaN        S
# 263  40.0      0      0  112059   0.0   B94        S
# 271  25.0      0      0    LINE   0.0   NaN        S
# 277   NaN      0      0  239853   0.0   NaN        S
# 302  19.0      0      0    LINE   0.0   NaN        S

# %%
numeric_cols_clean = [
    col for col in df.select_dtypes(include=['int', 'float']).columns
    if col not in columnas_a_excluir
]

scaler = MinMaxScaler()
df_clean = df.copy()
df_clean[numeric_cols_clean] = scaler.fit_transform(df_clean[numeric_cols_clean])

joblib.dump(scaler, 'minmax_scaler.pkl')

X = df[numeric_cols_clean]
y = df['Survived']  # Target: 0 = No, 1 = Yes

display(X.describe().round(2))
# Out:
#        Pclass     Sex     Age    Fare
# count  891.00  891.00  714.00  891.00
# mean     2.31    0.35   29.70   32.20
# std      0.84    0.48   14.53   49.69
# min      1.00    0.00    0.42    0.00
# 25%      2.00    0.00   20.12    7.91
# 50%      3.00    0.00   28.00   14.45
# 75%      3.00    1.00   38.00   31.00
# max      3.00    1.00   80.00  512.33

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# %%
clf = DecisionTreeClassifier()

# %%
clf.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier()

# %%
train_accuracy = clf.score(X_train, y_train)
print(train_accuracy)
# Out:
# 0.9775280898876404

# %%
y_pred = clf.predict(X_test)

# %%
scaler = MinMaxScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# %%
# 'Pclass', 'Sex', 'Age', 'Fare'
test_data = pd.DataFrame([[1, 0, 12, 150]], columns=X.columns)
test_data_scaled = scaler.transform(test_data)

# %%
test_data_scaled = scaler.transform(test_data)

prediction = clf.predict(test_data_scaled)
probabilities = clf.predict_proba(test_data_scaled)

print(f"Predicción para {test_data.values[0]}: {'Sobrevive' if prediction[0] == 1 else 'No sobrevive'}")
print(f"Probabilidades: No={probabilities[0][0]:.2f}, Sí={probabilities[0][1]:.2f}")
# Out:
# Predicción para [  1   1   1 150]: Sobrevive
# Probabilidades: No=0.00, Sí=1.00
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(

# %% [markdown]
# EXPERIMENTAL

# %%
clf = DecisionTreeClassifier(
    max_depth=100,
    min_samples_leaf=2,
    ccp_alpha=0.01
)
clf.fit(X_train_scaled, y_train)
# Out:
# DecisionTreeClassifier(ccp_alpha=0.01, max_depth=100, min_samples_leaf=2)

# %%
y_pred = clf.predict(X_test_scaled)
print("Arbol de Decision")
print(classification_report(y_test, y_pred))
print(pd.crosstab(y_test, y_pred, rownames=['Real'], colnames=['Predicho']))
# Out:
# Arbol de Decision
#               precision    recall  f1-score   support
#
#            0       0.81      0.89      0.84       157
#            1       0.81      0.70      0.75       111
#
#     accuracy                           0.81       268
#    macro avg       0.81      0.79      0.80       268
# weighted avg       0.81      0.81      0.81       268
#
# Predicho    0   1
# Real
# 0         139  18
# 1          33  78

# %%
proba = clf.predict_proba(test_data_scaled)
print(f"Probabilidades Árbol: No={proba[0][0]:.2f}, Sí={proba[0][1]:.2f}")
# Out:
# Probabilidades Árbol: No=0.84, Sí=0.16

# %% [markdown]
# EXPERIMENTAL 2

# %%
rf = RandomForestClassifier(n_estimators=100, max_depth=100, random_state=42)
rf.fit(X_train_scaled, y_train)
# Out:
# RandomForestClassifier(max_depth=100, random_state=42)

# %%
rf_proba = rf.predict_proba(test_data_scaled)
print(f"Probabilidades Random Forest: No={rf_proba[0][0]:.2f}, Sí={rf_proba[0][1]:.2f}")
# Out:
# Probabilidades Random Forest: No=0.42, Sí=0.58
